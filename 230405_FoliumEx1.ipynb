# %% [markdown]
# [nbviewer에서 보기](https://nbviewer.jupyter.org/github/minjikim7526/TIL/blob/master/230405_FoliumEx1.ipynb)

# %% [markdown]
# # Folium
# - 인터랙티브 지도 시각화 라이브러리
# - Leaflet을 사용할 수 있는 leaflet.js 라이브러리를 파이썬에서 연동
# - 지도 상의 마커에서 vector, raster, HTML 시각화 가능
# - Choropleth 시각화(통계, 색깔 등)
# - TileSet, Image, Video, GeoJSON, TopoJSON 연동

# %%
import numpy as np
import pandas as pd
import json
import requests
import branca
import folium
folium.__version__
# Out:
# '0.14.0'

# %%
# 지도 띄우기
m = folium.Map(location=[37.58451818405944, 126.97765864311016])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_250e45c87926820d4bc1a58a5065e2ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_250e45c87926820d4bc1a58a5065e2ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_250e45c87926820d4bc1a58a5065e2ab = L.map(
#                 &quot;map_250e45c87926820d4bc1a58a5065e2ab&quot;,
#                 {
#                     center: [37.58451818405944, 126.97765864311016],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41795191b133dbe30897fd92311922f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_250e45c87926820d4bc1a58a5065e2ab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map.html')

# %%
# !ls
# Out:
# 'ls'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
m = folium.Map(
  location = [37.53778764778582, 126.91781431298205],
  # 숫자가 클 수록 지도가 확대됨
  zoom_start=14,
  # 다양한 타일 선택 가능
  tiles='OpenStreetMap'
)

tooltip = "Click me!" # 마우스 가져다대면 뜨는 문구

folium.Marker(
    [37.521773702688314, 126.92436514189143],
    popup='<b>Yeouido Station</b>', # 마우스 클릭하면 뜨는 문구
    tooltip=tooltip,
    icon = folium.Icon(color='darkpurple', icon= 'info-sign')
).add_to(m)

folium.Marker(
    [37.53483502640803, 126.90254688409031],
    popup='<b>Dangsan Station</b>',
    tooltip=tooltip,
    icon = folium.Icon(color='green', icon= 'bookmark')
).add_to(m)

folium.Marker(
    [37.53081228186041, 126.96548769850526],
    popup='<b>Yongsan Station</b>',
    tooltip=tooltip,
    icon = folium.Icon(color='darkblue', icon= 'flag')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25f0ea78cda872964c3ea6069ae58365 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25f0ea78cda872964c3ea6069ae58365&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25f0ea78cda872964c3ea6069ae58365 = L.map(
#                 &quot;map_25f0ea78cda872964c3ea6069ae58365&quot;,
#                 {
#                     center: [37.53778764778582, 126.91781431298205],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26bb89023611c1913056bf84f4a2a5f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_25f0ea78cda872964c3ea6069ae58365);
#
#
#             var marker_bd85d6338ea955bf81a020667c45a9cf = L.marker(
#                 [37.521773702688314, 126.92436514189143],
#                 {}
#             ).addTo(map_25f0ea78cda872964c3ea6069ae58365);
#
#
#             var icon_6276131740a3dcb72297bdfdb67f8dc2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd85d6338ea955bf81a020667c45a9cf.setIcon(icon_6276131740a3dcb72297bdfdb67f8dc2);
#
#
#         var popup_df7c729b0e208a9a6a670b9288f3cfc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d24c3eb70b1d0d21400be53fcf4922a6 = $(`&lt;div id=&quot;html_d24c3eb70b1d0d21400be53fcf4922a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yeouido Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_df7c729b0e208a9a6a670b9288f3cfc2.setContent(html_d24c3eb70b1d0d21400be53fcf4922a6);
#
#
#
#         marker_bd85d6338ea955bf81a020667c45a9cf.bindPopup(popup_df7c729b0e208a9a6a670b9288f3cfc2)
#         ;
#
#
#
#
#             marker_bd85d6338ea955bf81a020667c45a9cf.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d279814f8d0af145631993ba860f07a8 = L.marker(
#                 [37.53483502640803, 126.90254688409031],
#                 {}
#             ).addTo(map_25f0ea78cda872964c3ea6069ae58365);
#
#
#             var icon_4d6cc314b7ef986d41276c8ea4d1ec4d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d279814f8d0af145631993ba860f07a8.setIcon(icon_4d6cc314b7ef986d41276c8ea4d1ec4d);
#
#
#         var popup_fce32dcae57f6e2e7c6b5a05267de059 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9101c6e6b7c871d2f321ae0039d005d0 = $(`&lt;div id=&quot;html_9101c6e6b7c871d2f321ae0039d005d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dangsan Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_fce32dcae57f6e2e7c6b5a05267de059.setContent(html_9101c6e6b7c871d2f321ae0039d005d0);
#
#
#
#         marker_d279814f8d0af145631993ba860f07a8.bindPopup(popup_fce32dcae57f6e2e7c6b5a05267de059)
#         ;
#
#
#
#
#             marker_d279814f8d0af145631993ba860f07a8.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0dfad4fe92064510622c1400884b140b = L.marker(
#                 [37.53081228186041, 126.96548769850526],
#                 {}
#             ).addTo(map_25f0ea78cda872964c3ea6069ae58365);
#
#
#             var icon_fd1ea268ada353a795985de240d07f3d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0dfad4fe92064510622c1400884b140b.setIcon(icon_fd1ea268ada353a795985de240d07f3d);
#
#
#         var popup_a836867139c9a5ddecad107d3224586b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4510f13c3f73f13e7ba788c7fdb476e = $(`&lt;div id=&quot;html_e4510f13c3f73f13e7ba788c7fdb476e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yongsan Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_a836867139c9a

# %%
from folium import plugins

m = folium.Map(
  location = [37.57160017780208, 127.00963299488895],
  zoom_start=11
)

icon_plane = plugins.BeautifyIcon(
    icon='plane',
    border_color='dark',
    text_color='darkblue',
    icon_shape='circle'
)

icon_flag = plugins.BeautifyIcon(
    icon='flag',
    border_color='green',
    text_color='green',
    icon_shape='triangle'
)

icon_number= plugins.BeautifyIcon(
    number=10,
    border_color='darkred',
    text_color='darkred',
    inner_icon_style='margen-top:0;'
)

folium.Marker(
    [37.564503292712146, 126.8013674608083],
    popup='Plane',
    icon = icon_plane
).add_to(m)

folium.Marker(
    [37.56601269006829, 126.89390387820599],
    popup='Number',
    icon = icon_number
).add_to(m)

folium.Marker(
    [37.5714325187977, 126.96816791412975],
    popup='Flag',
    icon = icon_flag
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04f17ff88a80bb532482d99beb306bf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04f17ff88a80bb532482d99beb306bf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04f17ff88a80bb532482d99beb306bf8 = L.map(
#                 &quot;map_04f17ff88a80bb532482d99beb306bf8&quot;,
#                 {
#                     center: [37.57160017780208, 127.00963299488895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c311abac14555b8b2cdf1c36179564ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_04f17ff88a80bb532482d99beb306bf8);
#
#
#             var marker_106e207e5a6128ceebc3a0057c940e29 = L.marker(
#                 [37.564503292712146, 126.8013674608083],
#                 {}
#             ).addTo(map_04f17ff88a80bb532482d99beb306bf8);
#
#
#             var beautify_icon_1765bc8ba0a14e3211e10772b82995fd = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;dark&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;plane&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;darkblue&quot;}
#             )
#             marker_106e207e5a6128ceebc3a0057c940e29.setIcon(beautify_icon_1765bc8ba0a14e3211e10772b82995fd);
#
#
#         var popup_31d7d5596983cc19c3ac37d278cb4907 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5710d09142725a7d18a1dfe7360af62 = $(`&lt;div id=&quot;html_c5710d09142725a7d18a1dfe7360af62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plane&lt;/div&gt;`)[0];
#                 popup_31d7d5596983cc19c3ac37d278cb4907.setContent(html_c5710d09142725a7d18a1dfe7360af62);
#
#
#
#         marker_106e207e5a6128ceebc3a0057c940e29.bindPopup(popup_31d7d5596983cc19c3ac37d278cb4907)
#         ;
#
#
#
#
#             var marker_503be66dafffad274f9dd07e179bbada = L.marker(
#                 [37.56601269006829, 126.89390387820599],
#                 {}
#             ).addTo(map_04f17ff88a80bb532482d99beb306bf8);
#
#
#             var beautify_icon_ba384898f4f0fd3abb31be4e123356fc = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;darkred&quot;, &quot;borderWidth&quot;: 3, &quot;innerIconStyle&quot;: &quot;margen-top:0;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 10, &quot;textColor&quot;: &quot;darkred&quot;}
#             )
#             marker_503be66dafffad274f9dd07e179bbada.setIcon(beautify_icon_ba384898f4f0fd3abb31be4e123356fc);
#
#
#         var popup_da444ddb3ad44888354068f57ddb4b7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5944e9a353700d1848788d5b2d42ae81 = $(`&lt;div id=&quot;html_5944e9a353700d1848788d5b2d42ae81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Number&lt;/div&gt;`)[0];
#                 popup_da444ddb3ad44888354068f57ddb4b7b.setContent(html_5944e9a353700d1848788d5b2d42ae81);
#
#
#
#         marker_503be66dafffad274f9dd07e179bbada.bindPopup(popup_da444ddb3ad44888354068f57ddb4b7b)
#         ;
#
#
#
#
#             var marker_fea42126ba28320a500368264fd712c2 = L.marker(
#                 [37.5714325187977, 126.96816791412975],
#                 {}
#             ).addTo(map_04f17ff88a80bb532482d99beb306bf8);
#
#
#             var beautify_icon_cfc4906e89ccf163396ff5674bc53798 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;flag&quot;, &quot;iconShape&quot;: &quot;triangle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;green&quot;}
#             )
#             marker_fea42126ba28320a500368264fd712c2.setIcon(beautify_icon_cfc4906e89ccf163396ff5674bc53798);
#
#
#         var popup_09b998b75a722cd6bf08ab51c33c89fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6836d4c261b502be2c7dfd3db3d9337 = $(`&lt;div id=&quot;html_c6836d4c2

# %%
# 보트 마커
# 보트의 방향, 바람의 방향, 풍속 등 표시

m = folium.Map([30,-180], zoom_start=3)

plugins.BoatMarker(
    location=(37.41981581237974, 130.31405933599876),
    heading=45,
    wind_heading=45,
    wind_speed=45,
    color='purple'
).add_to(m)

plugins.BoatMarker(
    location=(40.740174044071836, 131.48010557321078),
    heading=-20,
    wind_heading=25,
    wind_speed=15,
    color='darkblue'
).add_to(m)

plugins.BoatMarker(
    location=(33.7341591020158, 128.50334538310105),
    heading=30,
    wind_speed=40,
    wind_heading=80,
    color='red'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37f83a7e5cc810056d018a32341ba86b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.boatmarker/leaflet.boatmarker.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37f83a7e5cc810056d018a32341ba86b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37f83a7e5cc810056d018a32341ba86b = L.map(
#                 &quot;map_37f83a7e5cc810056d018a32341ba86b&quot;,
#                 {
#                     center: [30.0, -180.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90b0cb7244833e16ee7d6c3a1d38f9a2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37f83a7e5cc810056d018a32341ba86b);
#
#
#             var boat_marker_4240b36e6f791631db002c868ab295b8 = L.boatMarker(
#                 [37.41981581237974, 130.31405933599876],
#                 {&quot;color&quot;: &quot;purple&quot;}
#             ).addTo(map_37f83a7e5cc810056d018a32341ba86b);
#             boat_marker_4240b36e6f791631db002c868ab295b8.setHeadingWind(
#                 45,
#                 45,
#                 45
#             );
#
#
#             var boat_marker_6b165a81439963d8745d23b0645b191b = L.boatMarker(
#                 [40.740174044071836, 131.48010557321078],
#                 {&quot;color&quot;: &quot;darkblue&quot;}
#             ).addTo(map_37f83a7e5cc810056d018a32341ba86b);
#             boat_marker_6b165a81439963d8745d23b0645b191b.setHeadingWind(
#                 -20,
#                 15,
#                 25
#             );
#
#
#             var boat_marker_f30b93e2d2279d6308d77ddbe09be89a = L.boatMarker(
#                 [33.7341591020158, 128.50334538310105],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_37f83a7e5cc810056d018a32341ba86b);
#             boat_marker_f30b93e2d2279d6308d77ddbe09be89a.setHeadingWind(
#                 30,
#                 40,
#                 80
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
