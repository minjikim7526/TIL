# %%
import pandas as pd

# %%
# 엑셀파일 안 열릴 때 설치
! pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      -------------------------------------- 250.0/250.0 kB 5.1 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
kto_201901 = pd.read_excel('./files/kto_201901.xlsx', header=1, usecols='A:G', skipfooter=4)
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계
# 0  아시아주  765082  10837  1423  14087  125521  916950
# 1    일본  198805   2233   127    785    4576  206526
# 2    대만   86393     74    22    180    1285   87954
# 3    홍콩   34653     59     2     90    1092   35896
# 4   마카오    2506      2     0     17      45    2570

# %%
kto_201901.tail()
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  768  718  90    206    908   2690
# 63     기타대륙   33    4   0      1     16     54
# 64     국적미상   33    4   0      1     16     54
# 65     교포소계    0    0   0      0  15526  15526
# 66       교포    0    0   0      0  15526  15526

# %%
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
# | : or로 조건 여러개 연결하기
condition=(kto_201901['관광']==0) \
        | (kto_201901['상용']==0) \
        | (kto_201901['공용']==0) \
        | (kto_201901['유학/연수']==0)
kto_201901[condition]
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %%
kto_201901['기준년월']='2019-01'
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0  아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1    일본  198805   2233   127    785    4576  206526  2019-01
# 2    대만   86393     74    22    180    1285   87954  2019-01
# 3    홍콩   34653     59     2     90    1092   35896  2019-01
# 4   마카오    2506      2     0     17      45    2570  2019-01

# %%
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
continents_list = ['아시아주','미주','구주','대양주','아프리카주','기타대륙','교포소계']
continents_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

# %%
# 대륙은 걸러내겠다
# 대륙리스트에 없는 것들만 country 데이터프레임에 담음!
condition=(kto_201901.국적.isin(continents_list) == False)
kto_201901_country = kto_201901[condition]
kto_201901_country['국적'].unique()
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
kto_201901_country.tail()
# 대양주 기타, 아프리카 기타는 대륙 정보가 아님(작은 나라들 쫌쫌따리)
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준년월
# 59    대양주 기타  555    3   4      0     52    614  2019-01
# 61  남아프리카공화국  368    9   1      6    616   1000  2019-01
# 62   아프리카 기타  768  718  90    206    908   2690  2019-01
# 64      국적미상   33    4   0      1     16     54  2019-01
# 66        교포    0    0   0      0  15526  15526  2019-01

# %%
kto_201901_country_newindex = kto_201901_country.reset_index(drop=True)
# 인덱스 다시 설정하기

# %%
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월
# 0   일본  198805  2233  127    785  4576  206526  2019-01
# 1   대만   86393    74   22    180  1285   87954  2019-01
# 2   홍콩   34653    59    2     90  1092   35896  2019-01
# 3  마카오    2506     2    0     17    45    2570  2019-01
# 4   태국   34004    37  199     96  6998   41334  2019-01

# %%
# 수작업으로 카운트 한 것...
continents = ['아시아']*25 + ['아메리카']*5+['유럽']*23+['오세아니아']*3+['아프리카']*2+['기타대륙']+['교포']

# %%
print(continents)
# Out:
# ['아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아메리카', '아메리카', '아메리카', '아메리카', '아메리카', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '오세아니아', '오세아니아', '오세아니아', '아프리카', '아프리카', '기타대륙', '교포']

# %%
# 대륙 컬럼 추가
kto_201901_country_newindex['대륙'] = continents
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아

# %%
kto_201901_country_newindex.tail()
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준년월     대륙
# 55    대양주 기타  555    3   4      0     52    614  2019-01  오세아니아
# 56  남아프리카공화국  368    9   1      6    616   1000  2019-01   아프리카
# 57   아프리카 기타  768  718  90    206    908   2690  2019-01   아프리카
# 58      국적미상   33    4   0      1     16     54  2019-01   기타대륙
# 59        교포    0    0   0      0  15526  15526  2019-01     교포

# %%
kto_201901_country_newindex['관광객비율(%)'] = round(kto_201901_country_newindex['관광']/kto_201901_country_newindex['계']*100, 1)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3

# %%
kto_201901_country_newindex.sort_values(by='관광객비율(%)', ascending=False).head()
# ascending=False 내림차순
# Out:
#         국적      관광    상용   공용  유학/연수    기타       계     기준년월     대륙  관광객비율(%)
# 1       대만   86393    74   22    180  1285   87954  2019-01    아시아      98.2
# 3      마카오    2506     2    0     17    45    2570  2019-01    아시아      97.5
# 2       홍콩   34653    59    2     90  1092   35896  2019-01    아시아      96.5
# 0       일본  198805  2233  127    785  4576  206526  2019-01    아시아      96.3
# 55  대양주 기타     555     3    4      0    52     614  2019-01  오세아니아      90.4

# %%
tourist_sum = sum(kto_201901['관광'])
kto_201901_country_newindex['전체비율(%)'] = round(kto_201901_country_newindex['관광']/tourist_sum*100, 1)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3
#
#    전체비율(%)
# 0     11.2
# 1      4.9
# 2      2.0
# 3      0.1
# 4      1.9

# %%
kto_201901_country_newindex.sort_values(by='전체비율(%)', ascending=False).head()
# ascending=False 내림차순
# Out:
#     국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 17  중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 0   일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 1   대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 25  미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 2   홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
#
#     전체비율(%)
# 17     18.1
# 0      11.2
# 1       4.9
# 25      2.4
# 2       2.0

# %%
# 판다스로 피벗테이블 만들기(관광객비율 대륙별 평균)
kto_201901_country_newindex.pivot_table(values='관광객비율(%)', index='대륙', aggfunc = 'mean')
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   61.100000
# 아메리카   68.200000
# 아시아    59.624000
# 아프리카   32.700000
# 오세아니아  84.833333
# 유럽     63.826087

# %%
# 전체 과정을 함수로 만들기(다른 기간 파일에도 쉽게 적용하기 위함)
def create_kto_data(yy,mm):
    file_path = './files/kto_{}{}.xlsx'.format(yy,mm)
    df = pd.read_excel(file_path, header=1, usecols='A:G', skipfooter=4)
    df['기준년월'] = '{}-{}'.format(yy,mm)
    ignore_list = ['아시아주','미주','구주','대양주','아프리카주','기타대륙','교포소계']
    condition = (df['국적'].isin(ignore_list)==False)
    df_country = df[condition].reset_index(drop=True)
    continents = ['아시아']*25 + ['아메리카']*5+['유럽']*23+['오세아니아']*3+['아프리카']*2+['기타대륙']+['교포']
    df_country['대륙'] = continents
    df_country['관광객비율(%)'] = round(df_country['관광']/df_country['계']*100,1)
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광']/tourist_sum*100,1)
    return(df_country)

# %%
kto_test = create_kto_data(2018,11)
kto_test.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  293965  1810  159    514  3530  299978  2018-11  아시아      98.0
# 1   대만   86476    62   18    192  1417   88165  2018-11  아시아      98.1
# 2   홍콩   52721    51    2    141   875   53790  2018-11  아시아      98.0
# 3  마카오    3986     2    0     16    38    4042  2018-11  아시아      98.6
# 4   태국   41003    46  260     66  5606   46981  2018-11  아시아      87.3
#
#    전체비율(%)
# 0     26.0
# 1      7.6
# 2      4.7
# 3      0.4
# 4      3.6

# %%
for yy in range(2010,2021):
    for mm in range(1,13):
        mm_str = str(mm).zfill(2)
        yymm='{}{}'.format(yy,mm_str)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008
# 202009
# 202010
# 202011
# 202012

# %%
df = pd.DataFrame()

# %%
for yy in range(2010,2021):
    for mm in range(1,13):
        try:
            temp = create_kto_data(str(yy), str(mm).zfill(2))
            df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
        except:
            pass # 오류 나면 패스
df.info()
# Out:
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# C:\Users\MINJI\AppData\Local\Temp\ipykernel_16120\4120324240.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True) # 인덱스 없이 계속 붙여넣기
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7920 entries, 0 to 7919
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        7920 non-null   object
#  1   관광        7920 non-null   int64
#  2   상용        7920 non-null   int64
#  3   공용        7920 non-null   int64
#  4   유학/연수     7920 non-null   int64
#  5   기타        7920 non-null   int64
#  6   계         7920 non-null   int64
#  7   기준년월      7920 non-null   object
#  8   대륙        7920 non-null   object
#  9   관광객비율(%)  7919 non-null   float64
#  10  전체비율(%)   7920 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 680.8+ KB

# %%
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
df.to_excel('./files/kto_total_20230331.xlsx', index=False)

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform 

if platform.system() == 'Windows': 
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else: 
    print('Check your OS system')

# %%
plt.plot(df['기준년월'], df['관광'])
plt.show()

# %%
condition = df['국적']=='중국'
# condition = (df['국적'].isin(['중국'])==True)
df_filter = df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)
# 17      10.1
# 77      13.6
# 137      9.2
# 197     15.5
# 257     17.0

# %%
plt.figure(figsize=(12,4))
plt.plot(df_filter['기준년월'], df_filter['관광'])
plt.title('중국 국적의 관광객 추이')
plt.xlabel('기준년월')
plt.ylabel('관광객수')
plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])
plt.show()

# %%
# 시계열 그래프
cntry_list=['중국','일본','대만','미국','홍콩']
for cntry in cntry_list:
    condition=(df['국적']==cntry)
    df_filter = df[condition]
    plt.figure(figsize=(12,4))
    plt.plot(df_filter['기준년월'], df_filter['관광'])
    plt.title('{} 국적의 관광객 추이'.format(cntry))
    plt.xlabel('기준년월')
    plt.ylabel('관광객수')
    plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])
    plt.show()

# %%
# 히트맵 그래프
# 2010-01에서 연도만 뽑아내기(slice로 0,1,2,3)
# 0번자리부터 3번자리까지만 '년도'컬럼에 추가
df['년도']=df['기준년월'].str.slice(0,4)
# 2010-01에서 월만 뽑아내기(slice로 5,6)
# 5번자리부터 6번자리까지만 '월'컬럼에 추가
df['월']=df['기준년월'].str.slice(5,7)
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1
#
#    전체비율(%)    년도   월
# 0     50.6  2010  01
# 1      8.9  2010  01
# 2      3.5  2010  01
# 3      0.1  2010  01
# 4      3.3  2010  01

# %%
condition=(df['국적']=='중국')
df_filter=df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)    년도   월
# 17      10.1  2010  01
# 77      13.6  2010  02
# 137      9.2  2010  03
# 197     15.5  2010  04
# 257     17.0  2010  05

# %%
# 관광객수를 y축에는 년도, x축에는 월로 해서 펼치기
df_pivot=df_filter.pivot_table(values='관광', index='년도', columns='월')
df_pivot
# Out:
# 월         01      02      03      04      05      06      07      08      09  \
# 년도
# 2010   40425   60590   50330   84252   89056   87080  122432  142180   93545
# 2011   55070   53863   72003   86397   85668  108060  170524  178937  144704
# 2012  106606   74895  110965  166843  154841  179074  258907  268988  203857
# 2013  148118  169395  182850  250549  196306  280319  417991  472005  353359
# 2014  230706  219533  313400  429419  410971  429991  540683  588181  423133
# 2015  327225  413096  386386  536428  517154  223101  172075  372990  453670
# 2016  456636  424232  500018  601460  614636  671493  823016  747818  611538
# 2017  489256  458952  263788  158784  172527  181507  207099  226153  229172
# 2018  236825  237075  281020  283533  284317  303405  332657  360982  326438
# 2019  320113  324291  369165  410542  413949  395196  439699  451570  432018
# 2020  393336   49520    5040     522     179     246     258     212     481
#
# 월         10      11      12
# 년도
# 2010  107237   75686   58987
# 2011  141824  113856  101605
# 2012  204866  155503  148320
# 2013  249850  208175  210950
# 2014  459708  381118  345957
# 2015  518651  409635  381722
# 2016  588561  452082  456882
# 2017  244541  223743  260983
# 2018  382922  327664  345135
# 2019  476460  426849  433577
# 2020     367     382     411

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      -------------------------------------- 293.3/293.3 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\minji\miniconda3\envs\pythonex\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
plt.figure(figsize=(16,10))
# annot=True : 숫자 값 표시할건지(True), 색깔만 나올건지
# cmap : 색깔
sns.heatmap(df_pivot, annot=True, fmt='.0f', cmap='rocket_r')
plt.title('중국 관광객 히트맵')
plt.show()

# %%
for cntry in cntry_list:
    condition = (df['국적']==cntry)
    df_filter = df[condition]
    df_pivot=df_filter.pivot_table(values='관광', index='년도', columns='월')
    plt.figure(figsize=(16,10))
    sns.heatmap(df_pivot, annot=True, fmt='.0f', cmap='rocket_r')
    plt.title('{} 관광객 히트맵'.format(cntry))
    plt.show()
