# %% [markdown]
# [nbviewer로 지도 보기](https://nbviewer.org/github/minjikim7526/TIL/blob/master/230405_FoliumEx1_BoatMarker.ipynb)

# %% [markdown]
# # Folium
# - 인터랙티브 지도 시각화 라이브러리
# - Leaflet을 사용할 수 있는 leaflet.js 라이브러리를 파이썬에서 연동
# - 지도 상의 마커에서 vector, raster, HTML 시각화 가능
# - Choropleth 시각화(통계, 색깔 등)
# - TileSet, Image, Video, GeoJSON, TopoJSON 연동

# %%
import numpy as np
import pandas as pd
import json
import requests
import branca
import folium
folium.__version__
# Out:
# '0.14.0'

# %%
# 지도 띄우기
m = folium.Map(location=[37.58451818405944, 126.97765864311016])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_305625a215ab1fc0c9fbb44d258849f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_305625a215ab1fc0c9fbb44d258849f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_305625a215ab1fc0c9fbb44d258849f3 = L.map(
#                 &quot;map_305625a215ab1fc0c9fbb44d258849f3&quot;,
#                 {
#                     center: [37.58451818405944, 126.97765864311016],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd357d20d1e9e880e004b1c704a394ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_305625a215ab1fc0c9fbb44d258849f3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map.html')

# %%
# !ls
# Out:
# map.html  sample_data

# %%
m = folium.Map(
  location = [37.53778764778582, 126.91781431298205],
  # 숫자가 클 수록 지도가 확대됨
  zoom_start=14,
  # 다양한 타일 선택 가능
  tiles='OpenStreetMap'
)

tooltip = "Click me!" # 마우스 가져다대면 뜨는 문구

folium.Marker(
    [37.521773702688314, 126.92436514189143],
    popup='<b>Yeouido Station</b>', # 마우스 클릭하면 뜨는 문구
    tooltip=tooltip,
    icon = folium.Icon(color='darkpurple', icon= 'info-sign')
).add_to(m)

folium.Marker(
    [37.53483502640803, 126.90254688409031],
    popup='<b>Dangsan Station</b>',
    tooltip=tooltip,
    icon = folium.Icon(color='green', icon= 'bookmark')
).add_to(m)

folium.Marker(
    [37.53081228186041, 126.96548769850526],
    popup='<b>Yongsan Station</b>',
    tooltip=tooltip,
    icon = folium.Icon(color='darkblue', icon= 'flag')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f75f5f1e7bb07b0de60d9c6279a20cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f75f5f1e7bb07b0de60d9c6279a20cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f75f5f1e7bb07b0de60d9c6279a20cf = L.map(
#                 &quot;map_4f75f5f1e7bb07b0de60d9c6279a20cf&quot;,
#                 {
#                     center: [37.53778764778582, 126.91781431298205],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5218d67397b3726ce51631a857745d28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f75f5f1e7bb07b0de60d9c6279a20cf);
#
#
#             var marker_c895552e8f92b85a99a4a8c4214dc5b6 = L.marker(
#                 [37.521773702688314, 126.92436514189143],
#                 {}
#             ).addTo(map_4f75f5f1e7bb07b0de60d9c6279a20cf);
#
#
#             var icon_3e2fe29a54022ae47f92d83946b26372 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c895552e8f92b85a99a4a8c4214dc5b6.setIcon(icon_3e2fe29a54022ae47f92d83946b26372);
#
#
#         var popup_8735edd2de1b5d7edd5c07c14ab85134 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_797871186d823f68f43b0178ae0b62a3 = $(`&lt;div id=&quot;html_797871186d823f68f43b0178ae0b62a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yeouido Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_8735edd2de1b5d7edd5c07c14ab85134.setContent(html_797871186d823f68f43b0178ae0b62a3);
#
#
#
#         marker_c895552e8f92b85a99a4a8c4214dc5b6.bindPopup(popup_8735edd2de1b5d7edd5c07c14ab85134)
#         ;
#
#
#
#
#             marker_c895552e8f92b85a99a4a8c4214dc5b6.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9f50eeb934abc2dcd7eff967d2894f22 = L.marker(
#                 [37.53483502640803, 126.90254688409031],
#                 {}
#             ).addTo(map_4f75f5f1e7bb07b0de60d9c6279a20cf);
#
#
#             var icon_4bf924ce035af49d45368c4384582122 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f50eeb934abc2dcd7eff967d2894f22.setIcon(icon_4bf924ce035af49d45368c4384582122);
#
#
#         var popup_bd8ba00f781fc9c450d6e1a1c382950f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1837f169d5ad35afec0848d08b0b8d61 = $(`&lt;div id=&quot;html_1837f169d5ad35afec0848d08b0b8d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dangsan Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_bd8ba00f781fc9c450d6e1a1c382950f.setContent(html_1837f169d5ad35afec0848d08b0b8d61);
#
#
#
#         marker_9f50eeb934abc2dcd7eff967d2894f22.bindPopup(popup_bd8ba00f781fc9c450d6e1a1c382950f)
#         ;
#
#
#
#
#             marker_9f50eeb934abc2dcd7eff967d2894f22.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ae87bb23544f09c13779de1ff0da5eaf = L.marker(
#                 [37.53081228186041, 126.96548769850526],
#                 {}
#             ).addTo(map_4f75f5f1e7bb07b0de60d9c6279a20cf);
#
#
#             var icon_4f62d2d4f0a564c651f5e3330033afff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae87bb23544f09c13779de1ff0da5eaf.setIcon(icon_4f62d2d4f0a564c651f5e3330033afff);
#
#
#         var popup_6a0b9c241257ecf9c09f8872ceaeab27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_730c1ddcc39a32a0aeca5b58d39f83f0 = $(`&lt;div id=&quot;html_730c1ddcc39a32a0aeca5b58d39f83f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yongsan Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_6a0b9c241257e

# %%
from folium import plugins

m = folium.Map(
  location = [37.57160017780208, 127.00963299488895],
  zoom_start=11
)

icon_plane = plugins.BeautifyIcon(
    icon='plane',
    border_color='dark',
    text_color='darkblue',
    icon_shape='circle'
)

icon_flag = plugins.BeautifyIcon(
    icon='flag',
    border_color='green',
    text_color='green',
    icon_shape='triangle'
)

icon_number= plugins.BeautifyIcon(
    number=10,
    border_color='darkred',
    text_color='darkred',
    inner_icon_style='margen-top:0;'
)

folium.Marker(
    [37.564503292712146, 126.8013674608083],
    popup='Plane',
    icon = icon_plane
).add_to(m)

folium.Marker(
    [37.56601269006829, 126.89390387820599],
    popup='Number',
    icon = icon_number
).add_to(m)

folium.Marker(
    [37.5714325187977, 126.96816791412975],
    popup='Flag',
    icon = icon_flag
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52fb4ab2badf6b8e9333443ba6142edd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52fb4ab2badf6b8e9333443ba6142edd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52fb4ab2badf6b8e9333443ba6142edd = L.map(
#                 &quot;map_52fb4ab2badf6b8e9333443ba6142edd&quot;,
#                 {
#                     center: [37.57160017780208, 127.00963299488895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08425639b3e2e1f409560852a47d332f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52fb4ab2badf6b8e9333443ba6142edd);
#
#
#             var marker_32ab1940878fe1b1afc150b697956991 = L.marker(
#                 [37.564503292712146, 126.8013674608083],
#                 {}
#             ).addTo(map_52fb4ab2badf6b8e9333443ba6142edd);
#
#
#             var beautify_icon_6524f8ae4fd123582bb7b548d7e36d0e = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;dark&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;plane&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;darkblue&quot;}
#             )
#             marker_32ab1940878fe1b1afc150b697956991.setIcon(beautify_icon_6524f8ae4fd123582bb7b548d7e36d0e);
#
#
#         var popup_0b9249e0150123118761683a4eea20be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8f7a8326ab8d04a6e3bad65992a8d52 = $(`&lt;div id=&quot;html_c8f7a8326ab8d04a6e3bad65992a8d52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plane&lt;/div&gt;`)[0];
#                 popup_0b9249e0150123118761683a4eea20be.setContent(html_c8f7a8326ab8d04a6e3bad65992a8d52);
#
#
#
#         marker_32ab1940878fe1b1afc150b697956991.bindPopup(popup_0b9249e0150123118761683a4eea20be)
#         ;
#
#
#
#
#             var marker_8d48764e169321d769b7690186c9988f = L.marker(
#                 [37.56601269006829, 126.89390387820599],
#                 {}
#             ).addTo(map_52fb4ab2badf6b8e9333443ba6142edd);
#
#
#             var beautify_icon_d68e58ee6e170c3d3322ee6581ff64a7 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;darkred&quot;, &quot;borderWidth&quot;: 3, &quot;innerIconStyle&quot;: &quot;margen-top:0;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 10, &quot;textColor&quot;: &quot;darkred&quot;}
#             )
#             marker_8d48764e169321d769b7690186c9988f.setIcon(beautify_icon_d68e58ee6e170c3d3322ee6581ff64a7);
#
#
#         var popup_4f5c8709f8a09a1efa2ca208586801f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abefd3a582c685c1a971424ecef7b678 = $(`&lt;div id=&quot;html_abefd3a582c685c1a971424ecef7b678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Number&lt;/div&gt;`)[0];
#                 popup_4f5c8709f8a09a1efa2ca208586801f7.setContent(html_abefd3a582c685c1a971424ecef7b678);
#
#
#
#         marker_8d48764e169321d769b7690186c9988f.bindPopup(popup_4f5c8709f8a09a1efa2ca208586801f7)
#         ;
#
#
#
#
#             var marker_fb028d720c784ca102dc435b06c8ca88 = L.marker(
#                 [37.5714325187977, 126.96816791412975],
#                 {}
#             ).addTo(map_52fb4ab2badf6b8e9333443ba6142edd);
#
#
#             var beautify_icon_075ed33c490c243f58edc413a8928b8a = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;flag&quot;, &quot;iconShape&quot;: &quot;triangle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;green&quot;}
#             )
#             marker_fb028d720c784ca102dc435b06c8ca88.setIcon(beautify_icon_075ed33c490c243f58edc413a8928b8a);
#
#
#         var popup_fd4d0d0287869e5c56b86b570835a6d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b412cca702b1aa699a7e49949d139a9 = $(`&lt;div id=&quot;html_5b412cca7

# %%
# 보트 마커
# 보트의 방향, 바람의 방향, 풍속 등 표시

m = folium.Map([30,-180], zoom_start=3)

plugins.BoatMarker(
    location=(37.41981581237974, 130.31405933599876),
    heading=45,
    wind_heading=45,
    wind_speed=45,
    color='purple'
).add_to(m)

plugins.BoatMarker(
    location=(40.740174044071836, 131.48010557321078),
    heading=-20,
    wind_heading=25,
    wind_speed=15,
    color='darkblue'
).add_to(m)

plugins.BoatMarker(
    location=(33.7341591020158, 128.50334538310105),
    heading=30,
    wind_speed=40,
    wind_heading=80,
    color='red'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_099f65ff4a95036d67ac9013dffd541d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.boatmarker/leaflet.boatmarker.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_099f65ff4a95036d67ac9013dffd541d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_099f65ff4a95036d67ac9013dffd541d = L.map(
#                 &quot;map_099f65ff4a95036d67ac9013dffd541d&quot;,
#                 {
#                     center: [30.0, -180.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_748c3a7c115c568261ef3f83dda2d103 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_099f65ff4a95036d67ac9013dffd541d);
#
#
#             var boat_marker_cc081dd682f1ad781f4b121b88d3ead1 = L.boatMarker(
#                 [37.41981581237974, 130.31405933599876],
#                 {&quot;color&quot;: &quot;purple&quot;}
#             ).addTo(map_099f65ff4a95036d67ac9013dffd541d);
#             boat_marker_cc081dd682f1ad781f4b121b88d3ead1.setHeadingWind(
#                 45,
#                 45,
#                 45
#             );
#
#
#             var boat_marker_b7980becc1b97ba55fe7a37699f70a23 = L.boatMarker(
#                 [40.740174044071836, 131.48010557321078],
#                 {&quot;color&quot;: &quot;darkblue&quot;}
#             ).addTo(map_099f65ff4a95036d67ac9013dffd541d);
#             boat_marker_b7980becc1b97ba55fe7a37699f70a23.setHeadingWind(
#                 -20,
#                 15,
#                 25
#             );
#
#
#             var boat_marker_6d83e4e90877da60b4f40f783dba01c7 = L.boatMarker(
#                 [33.7341591020158, 128.50334538310105],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_099f65ff4a95036d67ac9013dffd541d);
#             boat_marker_6d83e4e90877da60b4f40f783dba01c7.setHeadingWind(
#                 30,
#                 40,
#                 80
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
