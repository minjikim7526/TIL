# %% [markdown]
# # Folium
# - 인터랙티브 지도 시각화 라이브러리
# - Leaflet을 사용할 수 있는 leaflet.js 라이브러리를 파이썬에서 연동
# - 지도 상의 마커에서 vector, raster, HTML 시각화 가능
# - Choropleth 시각화(통계, 색깔 등)
# - TileSet, Image, Video, GeoJSON, TopoJSON 연동

# %%
import numpy as np
import pandas as pd
import json
import requests
import branca
import folium
folium.__version__
# Out:
# '0.14.0'

# %%
# 지도 띄우기
m = folium.Map(location=[37.58451818405944, 126.97765864311016])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0d7ca91435862381f3e89e0b44e09ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0d7ca91435862381f3e89e0b44e09ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0d7ca91435862381f3e89e0b44e09ea = L.map(
#                 &quot;map_e0d7ca91435862381f3e89e0b44e09ea&quot;,
#                 {
#                     center: [37.58451818405944, 126.97765864311016],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79532839a2fb8032d6389819be369101 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e0d7ca91435862381f3e89e0b44e09ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('map.html')

# %%
# !ls
# Out:
# map.html  sample_data

# %%
m = folium.Map(
  location = [37.53778764778582, 126.91781431298205],
  # 숫자가 클 수록 지도가 확대됨
  zoom_start=14,
  # 다양한 타일 선택 가능
  tiles='OpenStreetMap'
)

tooltip = "Click me!" # 마우스 가져다대면 뜨는 문구

folium.Marker(
    [37.521773702688314, 126.92436514189143],
    popup='<b>Yeouido Station</b>', # 마우스 클릭하면 뜨는 문구
    tooltip=tooltip,
    icon = folium.Icon(color='darkpurple', icon= 'info-sign')
).add_to(m)

folium.Marker(
    [37.53483502640803, 126.90254688409031],
    popup='<b>Dangsan Station</b>',
    tooltip=tooltip,
    icon = folium.Icon(color='green', icon= 'bookmark')
).add_to(m)

folium.Marker(
    [37.53081228186041, 126.96548769850526],
    popup='<b>Yongsan Station</b>',
    tooltip=tooltip,
    icon = folium.Icon(color='darkblue', icon= 'flag')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe83d11e74390db5cd098b32e511198d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe83d11e74390db5cd098b32e511198d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe83d11e74390db5cd098b32e511198d = L.map(
#                 &quot;map_fe83d11e74390db5cd098b32e511198d&quot;,
#                 {
#                     center: [37.53778764778582, 126.91781431298205],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_952d02e5d062cb9cd4da42d5b2bfccc6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe83d11e74390db5cd098b32e511198d);
#
#
#             var marker_886058e35d3c491a87a2d0b4e07461ad = L.marker(
#                 [37.521773702688314, 126.92436514189143],
#                 {}
#             ).addTo(map_fe83d11e74390db5cd098b32e511198d);
#
#
#             var icon_0510c735e708050f72cdf86661c59dec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_886058e35d3c491a87a2d0b4e07461ad.setIcon(icon_0510c735e708050f72cdf86661c59dec);
#
#
#         var popup_4fa7da3cbced1f222ec8522f6298be8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ea2c9ff674c1912b6ac9aec977d44d5 = $(`&lt;div id=&quot;html_1ea2c9ff674c1912b6ac9aec977d44d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yeouido Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_4fa7da3cbced1f222ec8522f6298be8a.setContent(html_1ea2c9ff674c1912b6ac9aec977d44d5);
#
#
#
#         marker_886058e35d3c491a87a2d0b4e07461ad.bindPopup(popup_4fa7da3cbced1f222ec8522f6298be8a)
#         ;
#
#
#
#
#             marker_886058e35d3c491a87a2d0b4e07461ad.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1e6c78c8e6c0e55d2eb9ee4a69487861 = L.marker(
#                 [37.53483502640803, 126.90254688409031],
#                 {}
#             ).addTo(map_fe83d11e74390db5cd098b32e511198d);
#
#
#             var icon_fd8b8095aa22e6830226dbb376f7f37c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1e6c78c8e6c0e55d2eb9ee4a69487861.setIcon(icon_fd8b8095aa22e6830226dbb376f7f37c);
#
#
#         var popup_4f70820ca95b43828e3ca074d45c9f32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24472c9f3922fbef9d0ce92733c3ffc9 = $(`&lt;div id=&quot;html_24472c9f3922fbef9d0ce92733c3ffc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dangsan Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_4f70820ca95b43828e3ca074d45c9f32.setContent(html_24472c9f3922fbef9d0ce92733c3ffc9);
#
#
#
#         marker_1e6c78c8e6c0e55d2eb9ee4a69487861.bindPopup(popup_4f70820ca95b43828e3ca074d45c9f32)
#         ;
#
#
#
#
#             marker_1e6c78c8e6c0e55d2eb9ee4a69487861.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7fb33708e009c201892f1b1f33b90bcd = L.marker(
#                 [37.53081228186041, 126.96548769850526],
#                 {}
#             ).addTo(map_fe83d11e74390db5cd098b32e511198d);
#
#
#             var icon_b3176ba3e0901095a4e47116dc5bc0f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fb33708e009c201892f1b1f33b90bcd.setIcon(icon_b3176ba3e0901095a4e47116dc5bc0f7);
#
#
#         var popup_227e5009497d352897af90cba6d73270 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c9583646bc4ef34aba990e1743c331a = $(`&lt;div id=&quot;html_7c9583646bc4ef34aba990e1743c331a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yongsan Station&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_227e5009497d3

# %%
from folium import plugins

m = folium.Map(
  location = [37.57160017780208, 127.00963299488895],
  zoom_start=11
)

icon_plane = plugins.BeautifyIcon(
    icon='plane',
    border_color='dark',
    text_color='darkblue',
    icon_shape='circle'
)

icon_flag = plugins.BeautifyIcon(
    icon='flag',
    border_color='green',
    text_color='green',
    icon_shape='triangle'
)

icon_number= plugins.BeautifyIcon(
    number=10,
    border_color='darkred',
    text_color='darkred',
    inner_icon_style='margen-top:0;'
)

folium.Marker(
    [37.564503292712146, 126.8013674608083],
    popup='Plane',
    icon = icon_plane
).add_to(m)

folium.Marker(
    [37.56601269006829, 126.89390387820599],
    popup='Number',
    icon = icon_number
).add_to(m)

folium.Marker(
    [37.5714325187977, 126.96816791412975],
    popup='Flag',
    icon = icon_flag
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f31527f296951d8c0b2d048eda0bf17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f31527f296951d8c0b2d048eda0bf17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f31527f296951d8c0b2d048eda0bf17 = L.map(
#                 &quot;map_7f31527f296951d8c0b2d048eda0bf17&quot;,
#                 {
#                     center: [37.57160017780208, 127.00963299488895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2af7f214a7fcfcf790a15acec39104f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7f31527f296951d8c0b2d048eda0bf17);
#
#
#             var marker_b161aa52b05eb21ee9f0e91202e088a3 = L.marker(
#                 [37.564503292712146, 126.8013674608083],
#                 {}
#             ).addTo(map_7f31527f296951d8c0b2d048eda0bf17);
#
#
#             var beautify_icon_9374f067c2abbb21fba599e7156f1319 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;dark&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;plane&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;darkblue&quot;}
#             )
#             marker_b161aa52b05eb21ee9f0e91202e088a3.setIcon(beautify_icon_9374f067c2abbb21fba599e7156f1319);
#
#
#         var popup_bba7c8701336c49acd809486329d39c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97b8156a89367639149bca0a2b863969 = $(`&lt;div id=&quot;html_97b8156a89367639149bca0a2b863969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plane&lt;/div&gt;`)[0];
#                 popup_bba7c8701336c49acd809486329d39c7.setContent(html_97b8156a89367639149bca0a2b863969);
#
#
#
#         marker_b161aa52b05eb21ee9f0e91202e088a3.bindPopup(popup_bba7c8701336c49acd809486329d39c7)
#         ;
#
#
#
#
#             var marker_cf9e751da824c70586f62d7930bd116b = L.marker(
#                 [37.56601269006829, 126.89390387820599],
#                 {}
#             ).addTo(map_7f31527f296951d8c0b2d048eda0bf17);
#
#
#             var beautify_icon_8068696d3daeffd24c862ab4f7eca9dc = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;darkred&quot;, &quot;borderWidth&quot;: 3, &quot;innerIconStyle&quot;: &quot;margen-top:0;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 10, &quot;textColor&quot;: &quot;darkred&quot;}
#             )
#             marker_cf9e751da824c70586f62d7930bd116b.setIcon(beautify_icon_8068696d3daeffd24c862ab4f7eca9dc);
#
#
#         var popup_0d8d999738c3767252f187f4b274a4f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f2bcaae5bea7ac447c417ff7f46db6f = $(`&lt;div id=&quot;html_5f2bcaae5bea7ac447c417ff7f46db6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Number&lt;/div&gt;`)[0];
#                 popup_0d8d999738c3767252f187f4b274a4f1.setContent(html_5f2bcaae5bea7ac447c417ff7f46db6f);
#
#
#
#         marker_cf9e751da824c70586f62d7930bd116b.bindPopup(popup_0d8d999738c3767252f187f4b274a4f1)
#         ;
#
#
#
#
#             var marker_024c56866215905e912852d2b176ddb6 = L.marker(
#                 [37.5714325187977, 126.96816791412975],
#                 {}
#             ).addTo(map_7f31527f296951d8c0b2d048eda0bf17);
#
#
#             var beautify_icon_558906ecf7faca789060bcba87ef9709 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;flag&quot;, &quot;iconShape&quot;: &quot;triangle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;green&quot;}
#             )
#             marker_024c56866215905e912852d2b176ddb6.setIcon(beautify_icon_558906ecf7faca789060bcba87ef9709);
#
#
#         var popup_e72bd7f1d2771a5e21c5ff81f3be95ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3b8d37314df3adb0706c2f83d62deca = $(`&lt;div id=&quot;html_f3b8d3731

# %%
# 보트 마커
# 보트의 방향, 바람의 방향, 풍속 등 표시

m = folium.Map([30,-180], zoom_start=3)

plugins.BoatMarker(
    location=(37.41981581237974, 130.31405933599876),
    heading=45,
    wind_heading=45,
    wind_speed=45,
    color='purple'
).add_to(m)

plugins.BoatMarker(
    location=(40.740174044071836, 131.48010557321078),
    heading=-20,
    wind_heading=25,
    wind_speed=15,
    color='darkblue'
).add_to(m)

plugins.BoatMarker(
    location=(33.7341591020158, 128.50334538310105),
    heading=30,
    wind_speed=40,
    wind_heading=80,
    color='red'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_969d417434623a50eba35d363598345f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.boatmarker/leaflet.boatmarker.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_969d417434623a50eba35d363598345f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_969d417434623a50eba35d363598345f = L.map(
#                 &quot;map_969d417434623a50eba35d363598345f&quot;,
#                 {
#                     center: [30.0, -180.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2cc3a5331de4194f3d1fec1633286a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_969d417434623a50eba35d363598345f);
#
#
#             var boat_marker_5bc0b1198f1218964801f01528eacbd5 = L.boatMarker(
#                 [37.41981581237974, 130.31405933599876],
#                 {&quot;color&quot;: &quot;purple&quot;}
#             ).addTo(map_969d417434623a50eba35d363598345f);
#             boat_marker_5bc0b1198f1218964801f01528eacbd5.setHeadingWind(
#                 45,
#                 45,
#                 45
#             );
#
#
#             var boat_marker_ccbf82f279178d12a3dc6a5794711e2b = L.boatMarker(
#                 [40.740174044071836, 131.48010557321078],
#                 {&quot;color&quot;: &quot;darkblue&quot;}
#             ).addTo(map_969d417434623a50eba35d363598345f);
#             boat_marker_ccbf82f279178d12a3dc6a5794711e2b.setHeadingWind(
#                 -20,
#                 15,
#                 25
#             );
#
#
#             var boat_marker_2f83ca6b5a4ea58c74236bcbb720c774 = L.boatMarker(
#                 [33.7341591020158, 128.50334538310105],
#                 {&quot;color&quot;: &quot;red&quot;}
#             ).addTo(map_969d417434623a50eba35d363598345f);
#             boat_marker_2f83ca6b5a4ea58c74236bcbb720c774.setHeadingWind(
#                 30,
#                 40,
#                 80
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
